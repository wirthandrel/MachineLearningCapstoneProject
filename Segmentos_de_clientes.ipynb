# %%
import numpy as np
import pandas as pd
from IPython.display import display # Permite o uso de display() para DataFrames
import visuals2 as vs
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

try:
    data = pd.read_csv("dataset.csv")
    
    print("O conjunto de dados possui {} pontos com {} variáveis em cada.".format(*data.shape))
except:
    print ("Dataset could not be loaded. Is the dataset missing?")
# Out:
# O conjunto de dados possui 1000 pontos com 6 variáveis em cada.

# %%
data = data.iloc[np.random.permutation(len(data))]
display(data.head(n=10))
print("O conjunto de dados possui {} pontos com {} variáveis em cada.".format(*data.shape))
# Out:
#      frios_lacteos_congelados  alimento_basico  alimento_industrializado  \
# 385                      1.39            39.96                    121.91
# 708                     18.82            87.68                    115.72
# 642                     18.82            87.68                    115.72
# 289                     11.45            43.28                     92.79
# 241                      9.07            61.93                     65.63
# 888                      4.87             7.66                     50.30
# 578                     16.01            41.67                    150.46
# 611                     10.12            20.57                     80.07
# 1                        5.16            61.27                    107.71
# 766                     16.01            41.67                    150.46
#
#      material_de_limpeza  perfumaria_higiene_pessoal  bebidas
# 385                24.51                       22.16    13.55
# 708                50.02                       23.25    20.46
# 642                50.02                       23.25    20.46
# 289                42.48                       23.73    15.76
# 241                13.50                       18.37     9.41
# 888                17.39                       15.68     6.64
# 578                23.55                       57.45    20.88
# 611                31.57                       39.63    17.45
# 1                  20.06                       70.61    10.47
# 766                23.55                       57.45    20.88
# O conjunto de dados possui 1000 pontos com 6 variáveis em cada.

# %%
display(data.describe())
# Out:
#        frios_lacteos_congelados  alimento_basico  alimento_industrializado  \
# count               1000.000000      1000.000000                1000.00000
# mean                  10.564910        46.941700                  89.49046
# std                    5.295723        27.374487                  33.64815
# min                    1.390000         1.690000                  22.52000
# 25%                    5.160000        23.130000                  59.39000
# 50%                   10.120000        41.670000                  96.33000
# 75%                   14.560000        61.930000                 116.98000
# max                   21.600000        96.930000                 150.46000
#
#        material_de_limpeza  perfumaria_higiene_pessoal     bebidas
# count           1000.00000                 1000.000000  1000.00000
# mean              28.90430                   29.231080    14.88266
# std               16.66262                   16.937287     8.40738
# min                1.09000                    0.350000     2.97000
# 25%               20.04000                   20.440000     8.97000
# 50%               25.62000                   23.730000    13.55000
# 75%               31.57000                   39.630000    20.46000
# max               65.45000                   70.610000    33.69000

# %%
data.plot.hist(subplots=True, layout=(6,2), figsize=(10, 10), bins=15)
print("Distribuição dos dados")
# Out:
# Distribuição dos dados

# %%
import seaborn as sns; sns.set()

uniform_data =data.corr(method='pearson')

ax = sns.heatmap(uniform_data, annot=True)

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeRegressor

# Make a copy of the DataFrame, using the 'drop' function to drop the given feature
new_data = data.copy().drop('bebidas', 1)

# Split the data into training and testing sets using the given feature as the target
X_train, X_test, y_train, y_test = train_test_split(new_data, data['bebidas'], test_size=0.25, random_state=0)

# Create a decision tree regressor and fit it to the training set
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X_train, y_train)

# Report the score of the prediction using the testing set
score = regressor.score(X_test, y_test)
print ("Model has a coefficient of determination, R^2, of {:.3f}.".format(score))
# Out:
# Model has a coefficient of determination, R^2, of 1.000.

# %%
uniform_data =new_data.corr(method='pearson')

ax = sns.heatmap(uniform_data, annot=True)

# %%
# Make a copy of the DataFrame, using the 'drop' function to drop the given feature
new_data = new_data.copy().drop('perfumaria_higiene_pessoal', 1)

# Split the data into training and testing sets using the given feature as the target
X_train, X_test, y_train, y_test = train_test_split(new_data, data['perfumaria_higiene_pessoal'], test_size=0.25, random_state=0)

# Create a decision tree regressor and fit it to the training set
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X_train, y_train)

# Report the score of the prediction using the testing set
score = regressor.score(X_test, y_test)
print ("Model has a coefficient of determination, R^2, of {:.3f}.".format(score))
# Out:
# Model has a coefficient of determination, R^2, of 1.000.

# %%
uniform_data =new_data.corr(method='pearson')

ax = sns.heatmap(uniform_data, annot=True)

# %%
# Make a copy of the DataFrame, using the 'drop' function to drop the given feature
new_data = new_data.copy().drop('material_de_limpeza', 1)

# Split the data into training and testing sets using the given feature as the target
X_train, X_test, y_train, y_test = train_test_split(new_data, data['material_de_limpeza'], test_size=0.25, random_state=0)

# Create a decision tree regressor and fit it to the training set
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X_train, y_train)

# Report the score of the prediction using the testing set
score = regressor.score(X_test, y_test)
print ("Model has a coefficient of determination, R^2, of {:.3f}.".format(score))
# Out:
# Model has a coefficient of determination, R^2, of 1.000.

# %%
uniform_data =new_data.corr(method='pearson')

ax = sns.heatmap(uniform_data, annot=True)

# %%
#removendo colunas que possuem corelação
data= data.drop(['material_de_limpeza','perfumaria_higiene_pessoal','bebidas'], 1)

# %%
# TODO: Selecione três índices de sua escolha que você gostaria de obter como amostra do conjunto de dados
indices = [1, 200, 616, 800]

# Crie um DataFrame das amostras escolhidas
samples = pd.DataFrame(data.iloc[indices], columns = data.keys()).reset_index(drop = True)
print("Chosen samples of wholesale customers dataset:")
display(samples)
# Out:
# Chosen samples of wholesale customers dataset:
#    frios_lacteos_congelados  alimento_basico  alimento_industrializado
# 0                     18.82            87.68                    115.72
# 1                     14.56            23.13                    131.37
# 2                      5.16            61.27                    107.71
# 3                      5.16            33.07                     96.33

# %%
import seaborn as sns
samples_bar = samples
samples_bar.index = indices 
_ = samples_bar.plot(kind='bar', figsize=(14,6))

# %%
# Produza uma matriz de dispersão para cada um dos pares de atributos dos dados
pd.plotting.scatter_matrix(data, alpha = 0.3, figsize = (14,8), diagonal = 'kde');

# %%
# TODO: Escalone os dados utilizando o algoritmo natural
log_data = np.log(data)

# TODO: Escalone a amostra de dados utilizando o algoritmo natural
log_samples = np.log(samples)

# Produza uma matriz de dispersão para cada par de atributos novos-transformados
pd.plotting.scatter_matrix(log_data, alpha = 0.3, figsize = (14,8), diagonal = 'kde');
print("Destribuição dos dados após transformação logaritmica")
# Out:
# Destribuição dos dados após transformação logaritmica

# %%
outliers_list=[]
outliers_repeated=[] 
# Para cada atributo encontre os pontos de dados com máximos valores altos e baixos
for feature in log_data.keys():
    #print("feature: {}".format(feature))
    # TODO: Calcule Q1 (25º percentil dos dados) para o atributo dado
    Q1 = np.percentile(log_data[feature], 25)
    
    # TODO: Calcule Q3 (75º percentil dos dados) para o atributo dado
    Q3 = np.percentile(log_data[feature], 75)
    
    # TODO: Utilize a amplitude interquartil para calcular o passo do discrepante (1,5 vezes a variação interquartil)
    step = (Q3 - Q1) * 1.5
    
    # Mostre os discrepantes
    #print("Data points considered outliers for the feature '{}':".format(feature))
    outliers_log_data = log_data[~((log_data[feature] >= Q1 - step) & (log_data[feature] <= Q3 + step))]
    #display(outliers_log_data)
   
    for outlier in outliers_log_data.index:
        if outlier not in outliers_list:
            outliers_list.append(outlier)
        elif outlier not in outliers_repeated:
            outliers_repeated.append(outlier)    
    
# OPCIONAL: Selecione os índices dos pontos de dados que você deseja remover
outliers  = outliers_list + outliers_repeated

# Remova os valores aqui, caso nenhum tenha sido especificado
good_data = log_data.drop(log_data.index[outliers]).reset_index(drop = True)


#print("outliers duplicados {}".format(outliers_repeated))

# TODO: Escalone os dados utilizando o algoritmo natural
log_data = np.log(data)

# TODO: Escalone a amostra de dados utilizando o algoritmo natural
log_samples = np.log(samples)

# Produza uma matriz de dispersão para cada par de atributos novos-transformados
pd.plotting.scatter_matrix(log_data, alpha = 0.3, figsize = (14,8), diagonal = 'kde');
print("Destribuição dos dados após remoção dos outliers e transformação logaritmica")
# Out:
# Destribuição dos dados após remoção dos outliers e transformação logaritmica

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
best_score = 0
best_cluster_number = 0
for cluster_number in np.arange(2, 24, 3):

    # TODO: Aplique o algoritmo de clustering de sua escolha aos dados reduzidos 
    clusterer = KMeans(n_clusters=cluster_number).fit(log_data)

    # TODO: Preveja o cluster para cada ponto de dado
    preds = clusterer.predict(log_data)

    # TODO: Ache os centros do cluster
    centers = clusterer.cluster_centers_

    # TODO: Preveja o cluster para cada amostra de pontos de dado transformados
    sample_preds = clusterer.predict(log_samples)

    # TODO: Calcule a média do coeficiente de silhueta para o número de clusters escolhidos
    score = silhouette_score(log_data, preds)
    
    #print("Numero de cluster {} score {}".format(cluster_number, score))
    
    if(best_score < score):
        best_score = score
        best_cluster_number = cluster_number
        
print("Melhor score: {} numero de clusters {}".format(best_score, best_cluster_number))
# Out:
# Melhor score: 1.0 numero de clusters 23

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
best_score = 0
best_cluster_number = 0
for cluster_number in np.arange(2, 4):

    # TODO: Aplique o algoritmo de clustering de sua escolha aos dados reduzidos 
    clusterer = KMeans(n_clusters=cluster_number,random_state=32,algorithm = 'full' ).fit(log_data)
#,algorithm = 'elkan'
    # TODO: Preveja o cluster para cada ponto de dado
    preds = clusterer.predict(log_data)

    # TODO: Ache os centros do cluster
    centers = clusterer.cluster_centers_

    # TODO: Preveja o cluster para cada amostra de pontos de dado transformados
    sample_preds = clusterer.predict(log_samples)

    # TODO: Calcule a média do coeficiente de silhueta para o número de clusters escolhidos
    score = silhouette_score(log_data, preds)
    
    #print("Numero de cluster {} score {}".format(cluster_number, score))
    
    if(best_score < score):
        best_score = score
        best_cluster_number = cluster_number
        
print("Melhor score: {} numero de clusters {}".format(best_score, best_cluster_number))
# Out:
# Melhor score: 0.5082576082030261 numero de clusters 2

# %%
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score

best_num_clusters = 0
best_score = 0
best_cluster_number = 0
for cluster_number in np.arange(2, 24, 3):
    # Apply your clustering algorithm of choice to the reduced data
    clusterer = GaussianMixture(n_components=cluster_number, covariance_type='full')
    clusterer.fit(log_data)

    # Predict the cluster for each data point
    preds = clusterer.predict(log_data)

    # Find the cluster centers
    centers = clusterer.means_

    # Predict the cluster for each transformed sample data point
    sample_preds = clusterer.predict(log_samples)

    # Calculate the mean silhouette coefficient for the number of clusters chosen
    score = silhouette_score(log_data, preds)
    print ("Silhouette coefficient for {} clusters: {}".format(cluster_number, score))
    if(best_score < score):
        best_score = score
        best_cluster_number = cluster_number
        
print("Melhor score: {} numero de clusters {}".format(best_score, best_cluster_number))
# Out:
# Silhouette coefficient for 2 clusters: 0.3504025221168373
# Silhouette coefficient for 5 clusters: 0.47726121991037274
# Silhouette coefficient for 8 clusters: 0.6331886131243792
# Silhouette coefficient for 11 clusters: 0.7303999261113084
# Silhouette coefficient for 14 clusters: 0.8110201946990737
# Silhouette coefficient for 17 clusters: 0.9085602201020176
# Silhouette coefficient for 20 clusters: 0.9668654151566286
# Silhouette coefficient for 23 clusters: 1.0
# Melhor score: 1.0 numero de clusters 23

# %%
# Mostre os verdadeiros centros
segments = ['Segment {}'.format(i) for i in range(0,len(centers))]
true_centers = pd.DataFrame(np.round(centers), columns = data.keys())
true_centers.index = segments
display(true_centers)
# Out:
#             frios_lacteos_congelados  alimento_basico  \
# Segment 0                        2.0              3.0
# Segment 1                        3.0              3.0
# Segment 2                        2.0              4.0
# Segment 3                        2.0              2.0
# Segment 4                        3.0              4.0
# Segment 5                        0.0              4.0
# Segment 6                        3.0              3.0
# Segment 7                        1.0              4.0
# Segment 8                        3.0              2.0
# Segment 9                        2.0              4.0
# Segment 10                       1.0              1.0
# Segment 11                       2.0              3.0
# Segment 12                       2.0              4.0
# Segment 13                       2.0              1.0
# Segment 14                       2.0              3.0
# Segment 15                       3.0              5.0
# Segment 16                       3.0              4.0
# Segment 17                       3.0              4.0
# Segment 18                       3.0              2.0
# Segment 19                       2.0              4.0
# Segment 20                       3.0              3.0
# Segment 21                       2.0              4.0
# Segment 22                       2.0              4.0
#
#             alimento_industrializado
# Segment 0                        5.0
# Segment 1                        4.0
# Segment 2                        5.0
# Segment 3                        4.0
# Segment 4                        5.0
# Segment 5                        5.0
# Segment 6                        5.0
# Segment 7                        3.0
# Segment 8                        4.0
# Segment 9                        4.0
# Segment 10                       3.0
# Segment 11                       4.0
# Segment 12                       5.0
# Segment 13                       4.0
# Segment 14                       3.0
# Segment 15                       5.0
# Segment 16                       4.0
# Segment 17                       5.0
# Segment 18                       4.0
# Segment 19                       4.0
# Segment 20                       4.0
# Segment 21                       4.0
# Segment 22                       4.0

# %%
print(log_samples['frios_lacteos_congelados'])
# Out:
# 1      2.934920
# 200    2.678278
# 616    1.640937
# 800    1.640937
# Name: frios_lacteos_congelados, dtype: float64

# %%
import matplotlib.cm as cm
predictions = pd.DataFrame(preds, columns = ['Cluster'])
plot_data = pd.concat([predictions, log_data], axis = 1)

# Generate the cluster plot
fig, ax = plt.subplots(figsize = (14,8))

# Color map
cmap = cm.get_cmap('gist_rainbow')
#print(log_samples[:,0])
# Color the points based on assigned cluster
for i, cluster in plot_data.groupby('Cluster'):
    
    cluster.plot(ax = ax, kind = 'scatter', x = 'frios_lacteos_congelados', y = 'alimento_basico',  \
                 color = cmap((i)*1.0/(len(centers)-1)), label = 'Segments %i'%(i), s=30);
    
#for i, cluster in plot_data.groupby('Cluster'):
    
 #   cluster.plot(ax = ax, kind = 'scatter', x = 'frios_lacteos_congelados', y = 'alimento_basico',  \
  #               color = cmap((i)*1.0/(len(centers)-1)), label = 'Cluster %i'%(i), s=30);    

# Plot centers with indicators
for i, c in enumerate(centers):
    ax.scatter(x = c[0], y = c[1], color = 'white', edgecolors = 'black', \
               alpha = 1, linewidth = 2, marker = 'o', s=200);
    ax.scatter(x = c[0], y = c[1], marker='$%d$'%(i), alpha = 1, s=100);

    
# Plot transformed sample points 
ax.scatter(x = log_samples['frios_lacteos_congelados'], y = log_samples['alimento_basico'], \
           s = 150, linewidth = 4, color = 'black', marker = 'x');



# Set plot title
ax.set_title("Cluster Learning - Centroids Marked by Number\nTransformed Sample Data Marked by Black Cross");

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=len(data.columns))
pca.fit(good_data)

pca_samples = pca.transform(log_samples)

pca_results = vs.pca_results(good_data, pca)

# %%
# Mostre as previsões
#for i, pred in enumerate(sample_preds):
#    print("Sample point", i, "predicted to be in Cluster", pred)

# %%
from sklearn.decomposition import PCA
log_data = np.log(data)
log_samples = np.log(samples)
components = 2

pca = PCA(n_components=components).fit(log_data)

reduced_data = pca.transform(log_data)

pca_samples = pca.transform(log_samples)

colunas = np.arange(1, components+1)

reduced_data = pd.DataFrame(reduced_data, columns = colunas )
# Exiba a amostra de log-data depois de aplicada a transformação da PCA em duas dimensões
display(pd.DataFrame(np.round(pca_samples, 4), columns = colunas))
# Out:
#         1       2
# 0 -1.1713 -0.2942
# 1  0.0238 -0.6281
# 2 -0.2862  0.7086
# 3  0.2696  0.4339

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
best_score = 0
for cluster_number in np.arange(2, 24):

    # TODO: Aplique o algoritmo de clustering de sua escolha aos dados reduzidos 
    clusterer = KMeans(n_clusters=cluster_number,algorithm = 'full' ).fit(reduced_data)

    # TODO: Preveja o cluster para cada ponto de dado
    preds = clusterer.predict(reduced_data)

    # TODO: Ache os centros do cluster
    centers = clusterer.cluster_centers_

    # TODO: Preveja o cluster para cada amostra de pontos de dado transformados
    sample_preds = clusterer.predict(pca_samples)

    # TODO: Calcule a média do coeficiente de silhueta para o número de clusters escolhidos
    score = silhouette_score(log_data, preds)
    
   # print("Numero de cluster {} score {}".format(cluster_number, score))
    
    if(best_score < score):
        best_score = score
        
print("Melhor score: {}".format(best_score))
# Out:
# Melhor score: 1.0

# %%
# Create a DataFrame for the reduced data
reduced_data = pd.DataFrame(reduced_data, columns = ['Dimension 1', 'Dimension 2'])

# %%
# Display sample log-data after applying PCA transformation in two dimensions
display(pd.DataFrame(np.round(pca_samples, 4), columns = ['Dimension 1', 'Dimension 2']))
# Out:
#    Dimension 1  Dimension 2
# 0      -1.1713      -0.2942
# 1       0.0238      -0.6281
# 2      -0.2862       0.7086
# 3       0.2696       0.4339

# %%
vs.cluster_results(reduced_data, preds, centers, pca_samples)

# %%
# Visualize samples
import seaborn as sns
true_centers_bar = true_centers
_ = true_centers_bar.plot(kind='bar', figsize=(14,5))
